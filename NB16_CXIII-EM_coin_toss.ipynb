# %% [markdown]
# # Notebook 16: Expectation Maximization in practice

# %% [markdown]
# ## Learning Goal
# The goal of this notebook is to gain intuition for Expectation Maximization using a simple example involving coin tosses.
#
# ## Overview
#
# In Section XIV, we introduce Expectation-Maximization (EM) as a practical way to perform maximum likelihood estimation (MLE) even when some of the data is hidden (i.e in the presence of latent or hidden variables). To better understand EM, in this short notebook we'll explore a very simple coin-tossing example adapted from [Do and Batzoglou, Nat. Biotechnol. (2008)](https://www.nature.com/articles/nbt1406).
#
# Suppose that we are given two coins A and B with unkown bias $\theta_A$ and $\theta_B$, respectively. Our goal is to estimate the bias vector $\boldsymbol{\theta}= (\theta_A, \theta_B)$ from the outcomes of the following experiment:
#
# <blockquote>
# First choose one coin at random. Then toss the selected coin 10 times independently and record the number of heads observed. Repeat this procedure 5 times.
# </blockquote>
#
# Formally, let $z_i\in\{A,B\}$ be the coin selected in experiment $i$ and $x_i\in\{0,1,\cdots 10\}$ be the number heads recorded by tossing $z_i$ 10 times. Since we conduct $n=5$ such experiments, we can summarize the outcomes of these 50 tosses by two vectors: $\boldsymbol{x}=(x_1,x_2\cdots, x_5)$ and $\boldsymbol{z}=(z_1,z_2,\cdots, z_5)$.

# %% [markdown]
# ### Exercise 1: What if we know everything?
#
#  * Consider first the case where we have complete knowledge of the experiment, namely, both $\boldsymbol{x}$ and $\boldsymbol{z}$ are known. How would you intuitively estimate the biases of the two coins  $\boldsymbol{\theta}= (\theta_A, \theta_B)$ ?
#
# Answer: Assuming $\theta_A$ and $\theta_B$ represent the probabilities for each coin to yield head. Take the average number of heads for each coins across all experiments.
#
#  * What's the likelihood of observing the complete outcomes of these experiments? In other words, what is $P(\boldsymbol{x},\boldsymbol{z}| n,\boldsymbol{\theta} )$? You may assume this is a Bernoulli trial. Namely, every time coin A(B) is tossed, we have, with probability $\theta_A$($\theta_B$), that the outcome is heads.
#
# Answer: $\prod\limits_{i=1}^5 [{10 \choose x_{i}}{\theta_{A}}^{x_{i}}(1-\theta_{A})^{(10-x_{i})}]^{m}*[{10 \choose x_{i}}{\theta_{B}}^{x_{i}}(1-\theta_{B})^{(10-x_{i})}]^{5-m}$ where m is the number of times coin A is chosen.
#
#  * What's the Maximum Likelihood Estimator (MLE)? Is this consistent with your intuition?
#
# Answer: The ratio between the number of heads and the 50 total tosses.

# %% [markdown]
# ## Comparing MLE and EM
#
# To test your answer, let's do some numerics! We will compare the MLE estimates of biases with an Expectation Maximization procedure where we do not know ${\bf z}$. The following code computes our best guess for the biases using MLE -- assuming we know the identity of the coin used -- and compares it estimates arrived at using an EM procedure where we have no knowledge about which coin was being tossed (though we know the same coin was tossed 10 times).

# %%
import numpy as np
from scipy.special import comb
import math


def compute_likelihood(obs, n, pheads): # No surprise, it's Binomial!!!

    likelihood = comb(n, obs, exact=True)*(pheads**obs)*(1.0-pheads)**(n-obs)

    return likelihood

# generate experiments
num_coin_toss = 10 # each experiment contains num_coin_toss tosses
num_exp = 1000  # we perform 5 such experiments
theta_A_true = 0.8 
theta_B_true = 0.4
coin_choice = np.zeros(num_exp) # initialize: 0 for A and 1 for B
head_counts = np.zeros(num_exp)

# MLE 
MLE_A = 0.0
MLE_B = 0.0

# generate the outcomes of experiment
for i in np.arange(num_exp):
    
    if np.random.randint(2) == 0: # coin A is selected
        head_counts[i] = np.random.binomial(num_coin_toss , theta_A_true, 1) # toss coin A num_coin_toss times
        MLE_A = MLE_A +  head_counts[i] # add the number of heads observed to total headcounts 
    
    else: # coin B is selected 
        head_counts[i] = np.random.binomial(num_coin_toss , theta_B_true, 1) # toss coin B num_coin_toss times
        coin_choice[i] = 1  # record the selection of coin B during experiment i 
        MLE_B = MLE_B +  head_counts[i] # add the number of heads observed to total headcounts 
    
tail_counts = num_coin_toss - head_counts


# MLE is merely the proportion of heads for each coin toss
MLE_A = MLE_A / ((num_exp - np.count_nonzero(coin_choice))*num_coin_toss)
MLE_B = MLE_B / (np.count_nonzero(coin_choice)*num_coin_toss)



# initialize the pA(heads) and pB(heads), namely, coin biases
pA_heads = np.zeros(100); 
pB_heads = np.zeros(100); 

pA_heads[0] = 0.60 # initial guess
pB_heads[0] = 0.50 # initial guess

# E-M begins!
epsilon = 0.001   # error threshold
j = 0 # iteration counter
improvement = float('inf')

while (improvement > epsilon):
    
    expectation_A = np.zeros((num_exp,2), dtype=float) 
    expectation_B = np.zeros((num_exp,2), dtype=float)
    
    for i in np.arange(min(len(head_counts),len(tail_counts))):
        
        eH = head_counts[i]
        eT = tail_counts[i]
        
        # E step:
        lA = compute_likelihood(eH, num_coin_toss, pA_heads[j])
        lB = compute_likelihood(eH, num_coin_toss, pB_heads[j])
        
        weightA = lA / (lA + lB)
        weightB = lB / (lA + lB)
              
        expectation_A[i] = weightA*np.array([eH, eT])
        expectation_B[i] = weightB*np.array([eH, eT])

  
    # M step
    theta_A = np.sum(expectation_A, axis = 0)[0] / np.sum(expectation_A) 
    theta_B = np.sum(expectation_B, axis = 0)[0] / np.sum(expectation_B) 

    print('At iteration %d, theta_A = %2f,  theta_B = %2f' % (j, theta_A, theta_B))
    
    pA_heads[j+1] = sum(expectation_A)[0] / sum(sum(expectation_A)); 
    pB_heads[j+1] = sum(expectation_B)[0] / sum(sum(expectation_B)); 

    improvement = max( abs(np.array([pA_heads[j+1],pB_heads[j+1]]) - np.array([pA_heads[j],pB_heads[j]]) ))
    j = j+1

# END of E-M, print the outcome

print('E-M converges at iteration %d' %j)
print('RESULT:')
print('E-M: theta_A = %2f,  theta_B = %2f' % (theta_A, theta_B))
print('MLE with complete data: theta_A = %2f,  theta_B = %2f' % (MLE_A, MLE_B))
# Out:
# At iteration 0, theta_A = 0.693553,  theta_B = 0.482300
# At iteration 1, theta_A = 0.758537,  theta_B = 0.424968
# At iteration 2, theta_A = 0.786129,  theta_B = 0.402257
# At iteration 3, theta_A = 0.793685,  theta_B = 0.399670
# At iteration 4, theta_A = 0.796098,  theta_B = 0.400439
# At iteration 5, theta_A = 0.797104,  theta_B = 0.401179
# At iteration 6, theta_A = 0.797586,  theta_B = 0.401614
# E-M converges at iteration 7
# RESULT:
# E-M: theta_A = 0.797586,  theta_B = 0.401614
# MLE with complete data: theta_A = 0.795582,  theta_B = 0.398805

# %% [markdown]
# ### Exercise 2
#
#  * How fast does EM converge? Is the converged result close to what you'd get from MLE?
#
# Answer: Considering a 0.01 tolerance, EM converges around the 4 iteration
#
#  * Following Exercise 1, what's the objective function we're optimizing in the E-step? Does this function have a *unique global maximum*?
#
# Answer: The objective function we are trying to maximize is the variational free energy and it has a unique maximum at the true values of the biases.
#
#  * Compare both the results of MLE and EM to the actual bias (i.e. *theta_A_true*  and *theta_B_true* in the snippet above), comment on their performance.
#
# Answer: The true values are $\theta_A = 0.8$ and $\theta_B = 0.4$. For the values given by the initial run of the code are theta_A = 0.765867,  theta_B = 0.396945 for EM and theta_A = 0.766667,  theta_B = 0.350000 MLE with complete data. Compared to the true values, EM seems to be more accurate for this run. However, for different runs one might perform better than the other which is due to the to the large variance of sample expectation for such a low number of trials. Incresing the number of coin tosses to 10000 for example already drstically improves the results of both method to the point were both perform indistinguishably efficiently.

# %% [markdown]
# ## Final remarks: a few practical tricks
#
# From Exercise 2 and Section XIV, we know that the E-M algorithm often approximates the MLE even in the presence of latent (hidden variables). Like with most optimization methods for nonconcave functions, E-M only guarantees convergence to a local maximum of the objective function. For this reason, its performance can be boosted by running the EM procedure starting with multiple initial parameters.

# %% [markdown]
# ### Exercise 3
#
# * Now instead of having a fixed initial guess of coin biases (i.e. *pA_heads[0]* and *pB_heads[0]* in the snippet), draw these values uniformly at random from $[0,1]$ and run the E-M algorithm. Repeat this twenty times and report what you observed. What's the best initial guess that gives the closest estimate to the true parameters?
#
# * As we discussed in Section X (LinReg), **Maximum a posteriori (MAP)** estimation differs from MLE in that it employs an augmented objective function which incorporates a prior distribution over the quantities we want to estimate, and the prior distribution can be think of as a regularizer for the objective fuction used in MLE. Here we will explore how to extend E-M to MAP estimation.
#
#   (1) First derive the MAP estimate for the one-coin-flipping example, namely,
#   $$
#   \hat{{\theta}}_{MAP}(\boldsymbol{x}) = \arg\max_{\theta\in[0,1]} \log P(\boldsymbol{x}|n,{\theta} ) + \log P({\theta}),
#   $$
#   where
#   $$P(\boldsymbol{x}|n,{\theta}) = \prod_{i=1}^{10} \text{Binomial} (x_i|n,\theta)$$
#
#   $$P({\theta})=\mathcal{N}(\theta|\mu, \sigma)$$
#
#   (2) Based on (1), now modify the E-M snippet above to incorporate this prior distribution into the **M-step**. Comment on the performance. For the prior choice, try $P(\boldsymbol{\theta})=\mathcal{N}(\theta_A|0.83, 1)\mathcal{N}(\theta_B|0.37, 1)$.

# %%
import numpy as np
from scipy.special import comb
import math


def compute_likelihood(obs, n, pheads): # No surprise, it's Binomial!!!

    likelihood = comb(n, obs, exact=True)*(pheads**obs)*(1.0-pheads)**(n-obs)

    return likelihood

for n in range(20):
    print("Experiment number: " + str(n+1))
    # generate experiments
    num_coin_toss = 10 # each experiment contains num_coin_toss tosses
    num_exp = 5  # we perform 5 such experiments
    theta_A_true = 0.8 
    theta_B_true = 0.4
    coin_choice = np.zeros(num_exp) # initialize: 0 for A and 1 for B
    head_counts = np.zeros(num_exp)

    # MLE 
    MLE_A = 0.0
    MLE_B = 0.0

    # generate the outcomes of experiment
    for i in np.arange(num_exp):

        if np.random.randint(2) == 0: # coin A is selected
            head_counts[i] = np.random.binomial(num_coin_toss , theta_A_true, 1) # toss coin A num_coin_toss times
            MLE_A = MLE_A +  head_counts[i] # add the number of heads observed to total headcounts 

        else: # coin B is selected 
            head_counts[i] = np.random.binomial(num_coin_toss , theta_B_true, 1) # toss coin B num_coin_toss times
            coin_choice[i] = 1  # record the selection of coin B during experiment i 
            MLE_B = MLE_B +  head_counts[i] # add the number of heads observed to total headcounts 

    tail_counts = num_coin_toss - head_counts


    # MLE is merely the proportion of heads for each coin toss
#     MLE_A = MLE_A / ((num_exp - np.count_nonzero(coin_choice))*num_coin_toss)
#     MLE_B = MLE_B / (np.count_nonzero(coin_choice)*num_coin_toss)



    # initialize the pA(heads) and pB(heads), namely, coin biases
    pA_heads = np.zeros(100); 
    pB_heads = np.zeros(100); 
    print

    pA_heads[0] = np.random.uniform() # initial guess
    pB_heads[0] = np.random.uniform() # initial guess

    print("Initial Guess theta_a: ", pA_heads[0])
    print("Initial Guess theta_b: ", pB_heads[0])
    # E-M begins!
    epsilon = 0.001   # error threshold
    j = 0 # iteration counter
    improvement = float('inf')

    while (improvement > epsilon):

        expectation_A = np.zeros((num_exp,2), dtype=float) 
        expectation_B = np.zeros((num_exp,2), dtype=float)

        for i in np.arange(min(len(head_counts),len(tail_counts))):

            eH = head_counts[i]
            eT = tail_counts[i]

            # E step:
            lA = compute_likelihood(eH, num_coin_toss, pA_heads[j])
            lB = compute_likelihood(eH, num_coin_toss, pB_heads[j])

            weightA = lA / (lA + lB)
            weightB = lB / (lA + lB)

            expectation_A[i] = weightA*np.array([eH, eT])
            expectation_B[i] = weightB*np.array([eH, eT])


        # M step
        theta_A = np.sum(expectation_A, axis = 0)[0] / np.sum(expectation_A) 
        theta_B = np.sum(expectation_B, axis = 0)[0] / np.sum(expectation_B) 

#         print('At iteration %d, theta_A = %2f,  theta_B = %2f' % (j, theta_A, theta_B))

        pA_heads[j+1] = sum(expectation_A)[0] / sum(sum(expectation_A)); 
        pB_heads[j+1] = sum(expectation_B)[0] / sum(sum(expectation_B)); 

        improvement = max( abs(np.array([pA_heads[j+1],pB_heads[j+1]]) - np.array([pA_heads[j],pB_heads[j]]) ))
        j = j+1

    # END of E-M, print the outcome

    print('E-M converges at iteration %d' %j)
    print('RESULT:')
    print('E-M: theta_A = %2f,  theta_B = %2f' % (theta_A, theta_B))
    print("Average Error: ", (abs(theta_A_true-theta_A)+abs(theta_B_true-theta_B))/2)
#     print('MLE with complete data: theta_A = %2f,  theta_B = %2f' % (MLE_A, MLE_B))
    
    print()
# Out:
# Experiment number: 1
# Initial Guess theta_a:  0.32705434326475114
# Initial Guess theta_b:  0.15730311901855065
# E-M converges at iteration 7
# RESULT:
# E-M: theta_A = 0.792457,  theta_B = 0.336099
# Average Error:  0.035721606645532866
#
# Experiment number: 2
# Initial Guess theta_a:  0.11208782945701379
# Initial Guess theta_b:  0.9785876529308833
# E-M converges at iteration 6
# RESULT:
# E-M: theta_A = 0.419632,  theta_B = 0.420368
# Average Error:  0.20036792463304656
#
# Experiment number: 3
# Initial Guess theta_a:  0.8567282388663809
# Initial Guess theta_b:  0.6817115203220636
# E-M converges at iteration 4
# RESULT:
# E-M: theta_A = 0.899353,  theta_B = 0.350168
# Average Error:  0.07459237313534267
#
# Experiment number: 4
# Initial Guess theta_a:  0.66459158278143
# Initial Guess theta_b:  0.3204259923327909
# E-M converges at iteration 3
# RESULT:
# E-M: theta_A = 0.900048,  theta_B = 0.233560
# Average Error:  0.13324391699982888
#
# Experiment number: 5
# Initial Guess theta_a:  0.37935312891703343
# Initial Guess theta_b:  0.2347665646114584
# E-M converges at iteration 5
# RESULT:
# E-M: theta_A = 0.440105,  theta_B = 0.439895
# Average Error:  0.19989524156143607
#
# Experiment number: 6
# Initial Guess theta_a:  0.36255735786255483
# Initial Guess theta_b:  0.13314639311389564
# E-M converges at iteration 5
# RESULT:
# E-M: theta_A = 0.865429,  theta_B = 0.474899
# Average Error:  0.07016389090305947
#
# Experiment number: 7
# Initial Guess theta_a:  0.658294723368117
# Initial Guess theta_b:  0.9619677055027448
# E-M converges at iteration 9
# RESULT:
# E-M: theta_A = 0.492933,  theta_B = 0.784754
# Average Error:  0.3459105533427557
#
# Experiment number: 8
# Initial Guess theta_a:  0.4555254415890643
# Initial Guess theta_b:  0.35130990135175544
# E-M converges at iteration 5
# RESULT:
# E-M: theta_A = 0.899827,  theta_B = 0.333653
# Average Error:  0.08308674927583881
#
# Experiment number: 9
# Initial Guess theta_a:  0.6454291317745031
# Initial Guess theta_b:  0.12460294732893118
# E-M converges at iteration 9
# RESULT:
# E-M: theta_A = 0.760743,  theta_B = 0.404054
# Average Error:  0.021655296997023482
#
# Experiment number: 10
# Initial Guess theta_a:  0.36672425721630797
# Initial Guess theta_b:  0.5030595237627187
# E-M converges at iteration 10
# RESULT:
# E-M: theta_A = 0.479527,  theta_B = 0.895476
# Average Error:  0.40797430781744526
#
# Experiment number: 11
# Initial Guess theta_a:  0.7171524800911752
# Initial Guess theta_b:  0.7271987803710863
# E-M converges at iteration 3
# RESULT:
# E-M: theta_A = 0.799499,  theta_B = 0.800501
# Average Error:  0.2005005658453236
#
# Experiment number: 12
# Initial Guess theta_a:  0.02061144769099621
# Initial Guess theta_b:  0.49857111847507407
# E-M converges at iteration 3
# RESULT:
# E-M: theta_A = 0.000000,  theta_B = 0.399393
# Average Error:  0.40030325672225886
#
# Experiment number: 13
# Initial Guess theta_a:  0.8440619527424164
# Initial Guess theta_b:  0.45158305061819715
# E-M converges at iteration 6
# RESULT:
# E-M: theta_A = 0.726438,  theta_B = 0.342154
# Average Error:  0.06570420456778872
#
# Experiment number: 14
# Initial Guess theta_a:  0.4426214254431269
# Initial Guess theta_b:  0.8683315103096505
# E-M converges at iteration 10
# RESULT:
# E-M: theta_A = 0.553194,  theta_B = 0.724183
# Average Error:  0.2854944294839156
#
# Experiment number: 15
# Initial Guess theta_a:  0.18341588610392712
# Initial Guess theta_b:  0.35629849325245033
# E-M converges at iteration 11
# RESULT:
# E-M: theta_A = 0.701309,  theta_B = 0.877132
# Average Error:  0.2879111367960986
#
# Experiment number: 16
# Initial Guess theta_a:  0.023600999298262426
# Initial Guess theta_b:  0.43418665293269465
# E-M converges at iteration 4
# RESULT:
# E-M: theta_A = 0.204591,  theta_B = 0.800187
# Average Error:  0.49779789905276517
#
# Experiment number: 17
# Initial Guess theta_a:  0.008832152316117448
# Initial Guess theta_b:  0.5108895321842047
# E-M converges at iteration 10
# RESULT:
# E-M: theta_A = 0.478414,  theta_B = 0.562072
# Average Error:  0.24182923961632463
#
# Experiment number: 18
# Initial Guess theta_a:  0.1710173839992335
# Initial Guess theta_b:  0.47800209109848935
# E-M converges at iteration 16
# RESULT:
# E-M: theta_A = 0.273639,  theta_B = 0.776329
# Average Error:  0.4513449983360728
#
# Experiment number: 19
# Initial Guess theta_a:  0.5636673479830815
# Initial Guess theta_b:  0.29809517912165706
# E-M converges at iteration 10
# RESULT:
# E-M: theta_A = 0.843234,  theta_B = 0.836766
# Average Error:  0.24000003911260637
#
# Experiment number: 20
# Initial Guess theta_a:  0.0032570161876144255
# Initial Guess theta_b:  0.22716939539112269
# E-M converges at iteration 7
# RESULT:
# E-M: theta_A = 0.331989,  theta_B = 0.471094
# Average Error:  0.2695527679736722

# %% [markdown]
# 1) Answer: The best initial guesses are for experiment 9 with theta_a = 0.6454291317745031 and theta_b = 0.12460294732893118, with an average error of 0.021655296997023482.

# %% [markdown]
# 2) I know we have to take a derivative with respect to theta, but not really sure about how to perform the calculation.
